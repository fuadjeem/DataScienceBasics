# %%
import matplotlib
import matplotlib.pyplot as plt
matplotlib.__version__
# Out:
# '3.6.2'

# %%
plt.plot([1,4,5,6])#
plt.show()

# %%
plt.plot([1,4,5,6], [2,3,4,3], color = "red") # in this way it will take count x and y both

# %%
import numpy as np

# %%
x = np.linspace(0,10,100)
plt.plot(x, np.sin(x))
plt.show()

# %%
plt.plot(x, np.sin(x))
plt.plot(x, np.cos(x))
plt.show()
